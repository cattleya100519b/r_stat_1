# %% [markdown]
# # 4. 確率と確率変数
# ## 4.1 事象
# - 標本点 (sample point): 起こりうる結果 $x, \omega$
# - 標本空間 (sample space): 標本点をまとめた集合 $\Omega$
# - 事象 (event): 標本空間の部分集合

# %% [markdown]
# ## 4.2 確率と確率変数

# %% [markdown]
# ## 4.3 Rにおける確率変数の扱い
# ### 4.3.3 確率密度関数 $dunif$

# %%
curve(dunif, from = -1, to = 2)
